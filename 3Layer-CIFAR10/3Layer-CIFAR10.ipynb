# %% [markdown]
# # EE 297 - HW1: CIFAR-10
#
# This notebook was completed as a course requirement for EE297: Deep Learning in the University of the Philippines Diliman.
#
# ## Objectives:
# 1. Train a 3-layer MLP on the CIFAR-10 dataset to acheive the highest accuracy possible. Tune the hyperparameters, implement regularization and apply data augmentation to improve your results
# 2. Train a 3-layer Convolutional Neural Network on the CIFAR-10 dataset to acheive the highest accuracy possible. Tune the hyperparameters, implement regularization and apply data augmentation to improve your results

# %%
import torch
import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np

import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

from tensorboardX import SummaryWriter # Pytorch + Tensorboard integration

# %% [markdown]
# # I. Data Loading and Augmentation

# %% [markdown]
# ## Cutout Regularizer
#
# Cutout regularization randomly masks patches from the image before training. This improves regularization since the networks learns to classify even with sections blacked out. This regularizer also results to train loss typically being higher than test loss since the training domain is harder due to blacked out patches

# %%
# https://github.com/uoguelph-mlrg/Cutout/blob/master/util/cutout.py
class Cutout(object):
    """Randomly mask out one or more patches from an image.
    Args:
        n_holes (int): Number of patches to cut out of each image.
        length (int): The length (in pixels) of each square patch.
    """
    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)

        mask = np.ones((h, w), np.float32)

        for n in range(self.n_holes):
            y = np.random.randint(h)
            x = np.random.randint(w)

            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask

        return img

# %% [markdown]
# # Load Dataset and Apply Data Augmentation

# %%
normalize = transforms.Normalize(mean=[x / 255.0 for x in [125.3, 123.0, 113.9]], std=[x / 255.0 for x in [63.0, 62.1, 66.7]])

train_transform = transforms.Compose([])

train_transform.transforms.append(transforms.RandomCrop(32, padding=4))
train_transform.transforms.append(transforms.RandomHorizontalFlip())
train_transform.transforms.append(transforms.ToTensor())
train_transform.transforms.append(normalize)
#train_transform.transforms.append(Cutout(n_holes=1, length=16))

test_transform = transforms.Compose([
    transforms.ToTensor(),
    normalize])

trainset = torchvision.datasets.CIFAR10(root='/home/josen/datasets/CIFAR/data', train=True,
                                        download=True, transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='/home/josen/datasets/CIFAR/data', train=False,
                                       download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))

# %% [markdown]
# # II. Network Definitions

# %% [markdown]
# ## 3-Layer Multilayer Perceptron

# %%
class FCNet(nn.Module):
    def __init__(self):
        super(FCNet, self).__init__()
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(32*32*3, 1024)
        self.fc2 = nn.Linear(1024, 256)
        self.fc3 = nn.Linear(256, 10)

    def forward(self, x):
        
        x = x.view(-1, 32*32*3) # Flatten
        x = F.relu(self.fc1(x)) # Layer 1
        x = F.dropout(x)
        
        x = F.relu(self.fc2(x)) # Layer 2
        x = F.dropout(x)
        
        x = self.fc3(x) # Layer 3
        
        return x


fcnet = FCNet()

# %% [markdown]
# ## 3-Layer Convolutional Neural Network

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3,64, 3)
        self.bn1 = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 128, 3)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 512, 3)
        self.bn3 = nn.BatchNorm2d(512)
        self.fc1 = nn.Linear(512*6*6, 10)

    def forward(self, x):
        x = F.dropout(F.relu(self.bn1(self.conv1(x))), p = 0.2)
        x = self.pool(F.dropout(F.relu(self.bn2(self.conv2(x))), p = 0.2))
        x = self.pool(F.dropout(F.relu(self.bn3(self.conv3(x))), p = 0.2))
        x = x.view(-1, 512*6*6)
        x = self.fc1(x)
        return x


net = Net()

# %% [markdown]
# # III. Training

# %% [markdown]
# ## 3-Layer Multilayer Perceptron Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(fcnet.parameters(), lr=0.001, nesterov=True, weight_decay=5e-4, momentum = 0.9)
writer = SummaryWriter()

total_batches = 0
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[30, 60, 80], gamma=0.1)

for epoch in range(90):  # loop over the dataset multiple times
    
    print('Epoch ' + str(epoch))
    scheduler.step(epoch) # Adjust learning rate
    
    running_loss = 0.0
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data
                
        # CUDA    
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        fcnet.to(device)
        inputs, labels = inputs.to(device), labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = fcnet(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 400 == 399:    # print every 400 mini-batches
            print('Train Loss: %.3f' %
                  (running_loss / 400))
            writer.add_scalar('data/fcnet__train_loss', running_loss / 400, total_batches)
            running_loss = 0.0
            total_batches += 400
            
    total = 0
    correct = 0
    with torch.no_grad():
        running_test_loss = 0.0
        for data_test in testloader:
            images_test, labels_test = data_test
            images_test, labels_test = images_test.to(device), labels_test.to(device)
            outputs_test = fcnet(images_test)
            _, predicted_test = torch.max(outputs_test.data, 1)
            total += labels_test.size(0)
            correct += (predicted_test == labels_test).sum().item()
            
            running_test_loss += criterion(outputs_test, labels_test)
            
        writer.add_scalar('data/fcnet_test_acc', 100 * correct / total, epoch)
        writer.add_scalar('data/fcnet_test_loss', running_test_loss / len(testloader), epoch)
        
        print("Test Loss: %.3f" % (running_test_loss/len(testloader)))        
        print("Test Accuracy: %.3f" % (100 * correct / total))


print('Finished Training')
# Out:
# Epoch 0
# Train Loss: 2.172
# Train Loss: 2.043
# Train Loss: 2.005
# Test Loss: 1.870
# Test Accuracy: 33.080
# Epoch 1
# Train Loss: 1.927
# Train Loss: 1.911
# Train Loss: 1.916
# Test Loss: 1.793
# Test Accuracy: 36.060
# Epoch 2
# Train Loss: 1.870
# Train Loss: 1.858
# Train Loss: 1.868
# Test Loss: 1.774
# Test Accuracy: 36.820
# Epoch 3
# Train Loss: 1.842
# Train Loss: 1.847
# Train Loss: 1.836
# Test Loss: 1.733
# Test Accuracy: 38.690
# Epoch 4
# Train Loss: 1.802
# Train Loss: 1.816
# Train Loss: 1.808
# Test Loss: 1.707
# Test Accuracy: 39.960
# Epoch 5
# Train Loss: 1.787
# Train Loss: 1.781
# Train Loss: 1.794
# Test Loss: 1.690
# Test Accuracy: 40.080
# Epoch 6
# Train Loss: 1.771
# Train Loss: 1.792
# Train Loss: 1.767
# Test Loss: 1.678
# Test Accuracy: 40.330
# Epoch 7
# Train Loss: 1.763
# Train Loss: 1.760
# Train Loss: 1.758
# Test Loss: 1.646
# Test Accuracy: 41.900
# Epoch 8
# Train Loss: 1.744
# Train Loss: 1.760
# Train Loss: 1.743
# Test Loss: 1.658
# Test Accuracy: 41.470
# Epoch 9
# Train Loss: 1.724
# Train Loss: 1.741
# Train Loss: 1.752
# Test Loss: 1.636
# Test Accuracy: 42.070
# Epoch 10
# Train Loss: 1.722
# Train Loss: 1.720
# Train Loss: 1.731
# Test Loss: 1.631
# Test Accuracy: 41.810
# Epoch 11
# Train Loss: 1.710
# Train Loss: 1.716
# Train Loss: 1.717
# Test Loss: 1.612
# Test Accuracy: 42.660
# Epoch 12
# Train Loss: 1.714
# Train Loss: 1.706
# Train Loss: 1.717
# Test Loss: 1.620
# Test Accuracy: 43.050
# Epoch 13
# Train Loss: 1.692
# Train Loss: 1.710
# Train Loss: 1.685
# Test Loss: 1.614
# Test Accuracy: 42.580
# Epoch 14
# Train Loss: 1.693
# Train Loss: 1.694
# Train Loss: 1.697
# Test Loss: 1.611
# Test Accuracy: 42.640
# Epoch 15
# Train Loss: 1.681
# Train Loss: 1.694
# Train Loss: 1.703
# Test Loss: 1.614
# Test Accuracy: 42.170
# Epoch 16
# Train Loss: 1.696
# Train Loss: 1.677
# Train Loss: 1.678
# Test Loss: 1.596
# Test Accuracy: 42.960
# Epoch 17
# Train Loss: 1.671
# Train Loss: 1.677
# Train Loss: 1.676
# Test Loss: 1.611
# Test Accuracy: 42.940
# Epoch 18
# Train Loss: 1.666
# Train Loss: 1.681
# Train Loss: 1.665
# Test Loss: 1.586
# Test Accuracy: 44.610
# Epoch 19
# Train Loss: 1.663
# Train Loss: 1.663
# Train Loss: 1.659
# Test Loss: 1.585
# Test Accuracy: 43.570
# Epoch 20
# Train Loss: 1.668
# Train Loss: 1.669
# Train Loss: 1.652
# Test Loss: 1.604
# Test Accuracy: 42.980
# Epoch 21
# Train Loss: 1.663
# Train Loss: 1.651
# Train Loss: 1.665
# Test Loss: 1.590
# Test Accuracy: 44.020
# Epoch 22
# Train Loss: 1.648
# Train Loss: 1.651
# Train Loss: 1.649
# Test Loss: 1.579
# Test Accuracy: 44.110
# Epoch 23
# Train Loss: 1.659
# Train Loss: 1.643
# Train Loss: 1.646
# Test Loss: 1.561
# Test Accuracy: 44.560
# Epoch 24
# Train Loss: 1.650
# Train Loss: 1.642
# Train Loss: 1.656
# Test Loss: 1.581
# Test Accuracy: 43.890
# Epoch 25
# Train Loss: 1.648
# Train Loss: 1.645
# Train Loss: 1.649
# Test Loss: 1.573
# Test Accuracy: 44.650
# Epoch 26
# Train Loss: 1.669
# Train Loss: 1.641
# Train Loss: 1.626
# Test Loss: 1.571
# Test Accuracy: 44.100
# Epoch 27
# Train Loss: 1.630
# Train Loss: 1.652
# Train Loss: 1.626
# Test Loss: 1.562
# Test Accuracy: 44.320
# Epoch 28
# Train Loss: 1.627
# Train Loss: 1.623
# Train Loss: 1.637
# Test Loss: 1.562
# Test Accuracy: 44.520
# Epoch 29
# Train Loss: 1.632
# Train Loss: 1.645
# Train Loss: 1.635
# Test Loss: 1.563
# Test Accuracy: 44.800
# Epoch 30
# Train Loss: 1.617
# Train Loss: 1.624
# Train Loss: 1.624
# Test Loss: 1.555
# Test Accuracy: 44.460
# Epoch 31
# Train Loss: 1.610
# Train Loss: 1.608
# Train Loss: 1.596
# Test Loss: 1.552
# Test Accuracy: 44.390
# Epoch 32
# Train Loss: 1.602
# Train Loss: 1.601
# Train Loss: 1.605
# Test Loss: 1.549
# Test Accuracy: 45.390
# Epoch 33
# Train Loss: 1.608
# Train Loss: 1.585
# Train Loss: 1.591
# Test Loss: 1.546
# Test Accuracy: 45.490
# Epoch 34
# Train Loss: 1.596
# Train Loss: 1.575
# Train Loss: 1.595
# Test Loss: 1.534
# Test Accuracy: 46.010
# Epoch 35
# Train Loss: 1.607
# Train Loss: 1.587
# Train Loss: 1.589
# Test Loss: 1.528
# Test Accuracy: 45.060
# Epoch 36
# Train Loss: 1.596
# Train Loss: 1.585
# Train Loss: 1.572
# Test Loss: 1.524
# Test Accuracy: 45.990
# Epoch 37
# Train Loss: 1.587
# Train Loss: 1.577
# Train Loss: 1.582
# Test Loss: 1.533
# Test Accuracy: 45.900
# Epoch 38
# Train Loss: 1.588
# Train Loss: 1.577
# Train Loss: 1.588
# Test Loss: 1.531
# Test Accuracy: 45.590
# Epoch 39
# Train Loss: 1.572
# Train Loss: 1.579
# Train Loss: 1.576
# Test Loss: 1.528
# Test Accuracy: 45.620
# Epoch 40
# Train Loss: 1.571
# Train Loss: 1.577
# Train Loss: 1.585
# Test Loss: 1.539
# Test Accuracy: 45.770
# Epoch 41
# Train Loss: 1.581
# Train Loss: 1.588
# Train Loss: 1.583
# Test Loss: 1.533
# Test Accuracy: 45.440
# Epoch 42
# Train Loss: 1.580
# Train Loss: 1.569
# Train Loss: 1.587
# Test Loss: 1.530
# Test Accuracy: 45.740
# Epoch 43
# Train Loss: 1.573
# Train Loss: 1.585
# Train Loss: 1.571
# Test Loss: 1.525
# Test Accuracy: 46.260
# Epoch 44
# Train Loss: 1.583
# Train Loss: 1.571
# Train Loss: 1.571
# Test Loss: 1.529
# Test Accuracy: 45.790
# Epoch 45
# Train Loss: 1.569
# Train Loss: 1.576
# Train Loss: 1.580
# Test Loss: 1.521
# Test Accuracy: 46.110
# Epoch 46
# Train Loss: 1.580
# Train Loss: 1.574
# Train Loss: 1.575
# Test Loss: 1.524
# Test Accuracy: 45.970
# Epoch 47
# Train Loss: 1.586
# Train Loss: 1.574
# Train Loss: 1.565
# Test Loss: 1.513
# Test Accuracy: 46.560
# Epoch 48
# Train Loss: 1.572
# Train Loss: 1.565
# Train Loss: 1.574
# Test Loss: 1.507
# Test Accuracy: 46.630
# Epoch 49
# Train Loss: 1.575
# Train Loss: 1.567
# Train Loss: 1.579
# Test Loss: 1.517
# Test Accuracy: 46.070
# Epoch 50
# Train Loss: 1.567
# Train Loss: 1.566
# Train Loss: 1.571
# Test Loss: 1.516
# Test Accuracy: 46.320
# Epoch 51
# Train Loss: 1.568
# Train Loss: 1.558
# Train Loss: 1.584
# Test Loss: 1.509
# Test Accuracy: 46.670
# Epoch 52
# Train Loss: 1.575
# Train Loss: 1.558
# Train Loss: 1.559
# Test Loss: 1.519
# Test Accuracy: 46.240
# Epoch 53
# Train Loss: 1.568
# Train Loss: 1.567
# Train Loss: 1.562
# Test Loss: 1.508
# Test Accuracy: 45.980
# Epoch 54
# Train Loss: 1.567
# Train Loss: 1.587
# Train Loss: 1.551
# Test Loss: 1.516
# Test Accuracy: 46.660
# Epoch 55
# Train Loss: 1.574
# Train Loss: 1.560
# Train Loss: 1.585
# Test Loss: 1.519
# Test Accuracy: 45.910
# Epoch 56
# Train Loss: 1.567
# Train Loss: 1.551
# Train Loss: 1.566
# Test Loss: 1.510
# Test Accuracy: 46.560
# Epoch 57
# Train Loss: 1.555
# Train Loss: 1.567
# Train Loss: 1.577
# Test Loss: 1.519
# Test Accuracy: 46.100
# Epoch 58
# Train Loss: 1.572
# Train Loss: 1.547
# Train Loss: 1.560
# Test Loss: 1.511
# Test Accuracy: 46.250
# Epoch 59
# Train Loss: 1.557
# Train Loss: 1.565
# Train Loss: 1.559
# Test Loss: 1.507
# Test Accuracy: 46.240
# Epoch 60
# Train Loss: 1.566
# Train Loss: 1.578
# Train Loss: 1.557
# Test Loss: 1.508
# Test Accuracy: 46.130
# Epoch 61
# Train Loss: 1.559
# Train Loss: 1.546
# Train Loss: 1.556
# Test Loss: 1.511
# Test Accuracy: 47.200
# Epoch 62
# Train Loss: 1.569
# Train Loss: 1.565
# Train Loss: 1.550
# Test Loss: 1.511
# Test Accuracy: 46.180
# Epoch 63
# Train Loss: 1.561
# Train Loss: 1.549
# Train Loss: 1.564
# Test Loss: 1.519
# Test Accuracy: 45.990
# Epoch 64
# Train Loss: 1.577
# Train Loss: 1.562
# Train Loss: 1.545
# Test Loss: 1.509
# Test Accuracy: 46.060
# Epoch 65
# Train Loss: 1.555
# Train Loss: 1.553
# Train Loss: 1.553
# Test Loss: 1.516
# Test Accuracy: 45.860
# Epoch 66
# Train Loss: 1.554
# Train Loss: 1.553
# Train Loss: 1.570
# Test Loss: 1.502
# Test Accuracy: 46.480
# Epoch 67
# Train Loss: 1.548
# Train Loss: 1.579
# Train Loss: 1.548
# Test Loss: 1.522
# Test Accuracy: 46.180
# Epoch 68
# Train Loss: 1.560
# Train Loss: 1.560
# Train Loss: 1.555
# Test Loss: 1.512
# Test Accuracy: 46.250
# Epoch 69
# Train Loss: 1.564
# Train Loss: 1.563
# Train Loss: 1.561
# Test Loss: 1.513
# Test Accuracy: 46.090
# Epoch 70
# Train Loss: 1.555
# Train Loss: 1.553
# Train Loss: 1.561
# Test Loss: 1.510
# Test Accuracy: 46.590
# Epoch 71
# Train Loss: 1.544
# Train Loss: 1.562
# Train Loss: 1.562
# Test Loss: 1.508
# Test Accuracy: 45.880
# Epoch 72
# Train Loss: 1.567
# Train Loss: 1.543
# Train Loss: 1.551
# Test Loss: 1.516
# Test Accuracy: 46.440
# Epoch 73
# Train Loss: 1.578
# Train Loss: 1.562
# Train Loss: 1.549
# Test Loss: 1.512
# Test Accuracy: 46.480
# Epoch 74
# Train Loss: 1.551
# Train Loss: 1.556
# Train Loss: 1.540
# Test Loss: 1.513
# Test Accuracy: 45.860
# Epoch 75
# Train Loss: 1.567
# Train Loss: 1.565
# Train Loss: 1.547
# Test Loss: 1.511
# Test Accuracy: 46.380
# Epoch 76
# Train Loss: 1.566
# Train Loss: 1.556
# Train Loss: 1.550
# Test Loss: 1.518
# Test Accuracy: 46.750
# Epoch 77
# Train Loss: 1.558
# Train Loss: 1.551
# Train Loss: 1.561
# Test Loss: 1.501
# Test Accuracy: 46.940
# Epoch 78
# Train Loss: 1.560
# Train Loss: 1.560
# Train Loss: 1.545
# Test Loss: 1.507
# Test Accuracy: 47.050
# Epoch 79
# Train Loss: 1.546
# Train Loss: 1.547
# Train Loss: 1.560
# Test Loss: 1.505
# Test Accuracy: 46.810
# Epoch 80
# Train Loss: 1.548
# Train Loss: 1.555
# Train Loss: 1.552
# Test Loss: 1.507
# Test Accuracy: 46.100
# Epoch 81
# Train Loss: 1.545
# Train Loss: 1.574
# Train Loss: 1.547
# Test Loss: 1.504
# Test Accuracy: 46.350
# Epoch 82
# Train Loss: 1.552
# Train Loss: 1.542
# Train Loss: 1.560
# Test Loss: 1.517
# Test Accuracy: 46.060
# Epoch 83
# Train Loss: 1.550
# Train Loss: 1.553
# Train Loss: 1.565
# Test Loss: 1.511
# Test Accuracy: 46.200
# Epoch 84
# Train Loss: 1.549
# Train Loss: 1.567
# Train Loss: 1.550
# Test Loss: 1.505
# Test Accuracy: 46.380
# Epoch 85
# Train Loss: 1.554
# Train Loss: 1.556
# Train Loss: 1.569
# Test Loss: 1.510
# Test Accuracy: 46.410
# Epoch 86
# Train Loss: 1.555
# Train Loss: 1.546
# Train Loss: 1.557
# Test Loss: 1.504
# Test Accuracy: 46.980
# Epoch 87
# Train Loss: 1.566
# Train Loss: 1.558
# Train Loss: 1.552
# Test Loss: 1.502
# Test Accuracy: 47.040
# Epoch 88
# Train Loss: 1.553
# Train Loss: 1.545
# Train Loss: 1.552
# Test Loss: 1.510
# Test Accuracy: 46.640
# Epoch 89
# Train Loss: 1.545
# Train Loss: 1.570
# Train Loss: 1.547
# Test Loss: 1.513
# Test Accuracy: 46.000
# Finished Training

# %% [markdown]
# ## 3-Layer Convolutional Neural Network Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, nesterov=True, weight_decay=5e-4, momentum = 0.9)
writer = SummaryWriter()

total_batches = 0
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[50, 100, 150], gamma=0.1)

for epoch in range(200):  # loop over the dataset multiple times
    
    print('Epoch ' + str(epoch))
    scheduler.step(epoch) # Adjust learning rate
    
    running_loss = 0.0
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data
                
        # CUDA    
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        net.to(device)
        inputs, labels = inputs.to(device), labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 400 == 399:    # print every 400 mini-batches
            print('Train Loss: %.3f' %
                  (running_loss / 400))
            writer.add_scalar('data/net__train_loss', running_loss / 400, total_batches)
            running_loss = 0.0
            total_batches += 400
            
    total = 0
    correct = 0
    with torch.no_grad():
        running_test_loss = 0.0
        for data_test in testloader:
            images_test, labels_test = data_test
            images_test, labels_test = images_test.to(device), labels_test.to(device)
            outputs_test = net(images_test)
            _, predicted_test = torch.max(outputs_test.data, 1)
            total += labels_test.size(0)
            correct += (predicted_test == labels_test).sum().item()
            
            running_test_loss += criterion(outputs_test, labels_test)
            
        writer.add_scalar('data/net_test_acc', 100 * correct / total, epoch)
        writer.add_scalar('data/net_test_loss', running_test_loss / len(testloader), epoch)
        
        print("Test Loss: %.3f" % (running_test_loss/len(testloader)))        
        print("Test Accuracy: %.3f" % (100 * correct / total))


print('Finished Training')
# Out:
# Epoch 0
# Train Loss: 1.802
# Train Loss: 1.554
# Train Loss: 1.416
# Test Loss: 1.192
# Test Accuracy: 58.090
# Epoch 1
# Train Loss: 1.269
# Train Loss: 1.226
# Train Loss: 1.177
# Test Loss: 1.015
# Test Accuracy: 64.560
# Epoch 2
# Train Loss: 1.146
# Train Loss: 1.094
# Train Loss: 1.100
# Test Loss: 0.898
# Test Accuracy: 68.850
# Epoch 3
# Train Loss: 1.033
# Train Loss: 1.031
# Train Loss: 1.015
# Test Loss: 0.945
# Test Accuracy: 67.280
# Epoch 4
# Train Loss: 0.973
# Train Loss: 0.972
# Train Loss: 0.953
# Test Loss: 0.815
# Test Accuracy: 71.980
# Epoch 5
# Train Loss: 0.922
# Train Loss: 0.935
# Train Loss: 0.903
# Test Loss: 0.834
# Test Accuracy: 71.260
# Epoch 6
# Train Loss: 0.888
# Train Loss: 0.889
# Train Loss: 0.878
# Test Loss: 0.832
# Test Accuracy: 71.030
# Epoch 7
# Train Loss: 0.840
# Train Loss: 0.858
# Train Loss: 0.862
# Test Loss: 0.739
# Test Accuracy: 74.420
# Epoch 8
# Train Loss: 0.812
# Train Loss: 0.823
# Train Loss: 0.800
# Test Loss: 0.737
# Test Accuracy: 74.530
# Epoch 9
# Train Loss: 0.783
# Train Loss: 0.779
# Train Loss: 0.780
# Test Loss: 0.698
# Test Accuracy: 75.830
# Epoch 10
# Train Loss: 0.767
# Train Loss: 0.776
# Train Loss: 0.760
# Test Loss: 0.700
# Test Accuracy: 76.030
# Epoch 11
# Train Loss: 0.748
# Train Loss: 0.740
# Train Loss: 0.741
# Test Loss: 0.681
# Test Accuracy: 76.490
# Epoch 12
# Train Loss: 0.731
# Train Loss: 0.724
# Train Loss: 0.723
# Test Loss: 0.688
# Test Accuracy: 76.120
# Epoch 13
# Train Loss: 0.709
# Train Loss: 0.716
# Train Loss: 0.710
# Test Loss: 0.656
# Test Accuracy: 77.550
# Epoch 14
# Train Loss: 0.691
# Train Loss: 0.696
# Train Loss: 0.719
# Test Loss: 0.653
# Test Accuracy: 77.660
# Epoch 15
# Train Loss: 0.666
# Train Loss: 0.691
# Train Loss: 0.670
# Test Loss: 0.622
# Test Accuracy: 78.790
# Epoch 16
# Train Loss: 0.661
# Train Loss: 0.658
# Train Loss: 0.669
# Test Loss: 0.625
# Test Accuracy: 78.300
# Epoch 17
# Train Loss: 0.650
# Train Loss: 0.651
# Train Loss: 0.648
# Test Loss: 0.621
# Test Accuracy: 78.990
# Epoch 18
# Train Loss: 0.651
# Train Loss: 0.643
# Train Loss: 0.638
# Test Loss: 0.593
# Test Accuracy: 79.490
# Epoch 19
# Train Loss: 0.635
# Train Loss: 0.629
# Train Loss: 0.625
# Test Loss: 0.630
# Test Accuracy: 78.620
# Epoch 20
# Train Loss: 0.600
# Train Loss: 0.624
# Train Loss: 0.621
# Test Loss: 0.587
# Test Accuracy: 80.110
# Epoch 21
# Train Loss: 0.616
# Train Loss: 0.609
# Train Loss: 0.610
# Test Loss: 0.595
# Test Accuracy: 79.580
# Epoch 22
# Train Loss: 0.596
# Train Loss: 0.607
# Train Loss: 0.614
# Test Loss: 0.578
# Test Accuracy: 80.270
# Epoch 23
# Train Loss: 0.581
# Train Loss: 0.590
# Train Loss: 0.605
# Test Loss: 0.564
# Test Accuracy: 80.770
# Epoch 24
# Train Loss: 0.564
# Train Loss: 0.573
# Train Loss: 0.591
# Test Loss: 0.583
# Test Accuracy: 79.770
# Epoch 25
# Train Loss: 0.579
# Train Loss: 0.575
# Train Loss: 0.559
# Test Loss: 0.586
# Test Accuracy: 79.490
# Epoch 26
# Train Loss: 0.571
# Train Loss: 0.569
# Train Loss: 0.564
# Test Loss: 0.552
# Test Accuracy: 81.150
# Epoch 27
# Train Loss: 0.554
# Train Loss: 0.563
# Train Loss: 0.567
# Test Loss: 0.552
# Test Accuracy: 80.760
# Epoch 28
# Train Loss: 0.540
# Train Loss: 0.545
# Train Loss: 0.556
# Test Loss: 0.566
# Test Accuracy: 80.720
# Epoch 29
# Train Loss: 0.546
# Train Loss: 0.548
# Train Loss: 0.547
# Test Loss: 0.544
# Test Accuracy: 81.630
# Epoch 30
# Train Loss: 0.539
# Train Loss: 0.531
# Train Loss: 0.554
# Test Loss: 0.566
# Test Accuracy: 80.440
# Epoch 31
# Train Loss: 0.538
# Train Loss: 0.531
# Train Loss: 0.537
# Test Loss: 0.545
# Test Accuracy: 81.140
# Epoch 32
# Train Loss: 0.528
# Train Loss: 0.523
# Train Loss: 0.522
# Test Loss: 0.550
# Test Accuracy: 81.280
# Epoch 33
# Train Loss: 0.518
# Train Loss: 0.516
# Train Loss: 0.520
# Test Loss: 0.532
# Test Accuracy: 81.340
# Epoch 34
# Train Loss: 0.517
# Train Loss: 0.521
# Train Loss: 0.515
# Test Loss: 0.525
# Test Accuracy: 81.850
# Epoch 35
# Train Loss: 0.512
# Train Loss: 0.494
# Train Loss: 0.521
# Test Loss: 0.536
# Test Accuracy: 81.830
# Epoch 36
# Train Loss: 0.501
# Train Loss: 0.506
# Train Loss: 0.496
# Test Loss: 0.544
# Test Accuracy: 81.480
# Epoch 37
# Train Loss: 0.476
# Train Loss: 0.499
# Train Loss: 0.502
# Test Loss: 0.519
# Test Accuracy: 82.350
# Epoch 38
# Train Loss: 0.486
# Train Loss: 0.486
# Train Loss: 0.495
# Test Loss: 0.535
# Test Accuracy: 81.490
# Epoch 39
# Train Loss: 0.499
# Train Loss: 0.490
# Train Loss: 0.481
# Test Loss: 0.522
# Test Accuracy: 81.870
# Epoch 40
# Train Loss: 0.471
# Train Loss: 0.480
# Train Loss: 0.488
# Test Loss: 0.524
# Test Accuracy: 81.950
# Epoch 41
# Train Loss: 0.473
# Train Loss: 0.493
# Train Loss: 0.478
# Test Loss: 0.510
# Test Accuracy: 82.570
# Epoch 42
# Train Loss: 0.462
# Train Loss: 0.475
# Train Loss: 0.489
# Test Loss: 0.512
# Test Accuracy: 82.880
# Epoch 43
# Train Loss: 0.474
# Train Loss: 0.466
# Train Loss: 0.471
# Test Loss: 0.511
# Test Accuracy: 82.130
# Epoch 44
# Train Loss: 0.459
# Train Loss: 0.471
# Train Loss: 0.471
# Test Loss: 0.518
# Test Accuracy: 82.760
# Epoch 45
# Train Loss: 0.460
# Train Loss: 0.465
# Train Loss: 0.468
# Test Loss: 0.517
# Test Accuracy: 82.150
# Epoch 46
# Train Loss: 0.447
# Train Loss: 0.467
# Train Loss: 0.464
# Test Loss: 0.514
# Test Accuracy: 82.990
# Epoch 47
# Train Loss: 0.443
# Train Loss: 0.451
# Train Loss: 0.463
# Test Loss: 0.494
# Test Accuracy: 83.150
# Epoch 48
# Train Loss: 0.457
# Train Loss: 0.442
# Train Loss: 0.455
# Test Loss: 0.501
# Test Accuracy: 83.090
# Epoch 49
# Train Loss: 0.442
# Train Loss: 0.450
# Train Loss: 0.461
# Test Loss: 0.494
# Test Accuracy: 82.980
# Epoch 50
# Train Loss: 0.419
# Train Loss: 0.398
# Train Loss: 0.408
# Test Loss: 0.466
# Test Accuracy: 84.050
# Epoch 51
# Train Loss: 0.382
# Train Loss: 0.393
# Train Loss: 0.395
# Test Loss: 0.459
# Test Accuracy: 84.390
# Epoch 52
# Train Loss: 0.381
# Train Loss: 0.390
# Train Loss: 0.382
# Test Loss: 0.463
# Test Accuracy: 84.440
# Epoch 53
# Train Loss: 0.375
# Train Loss: 0.384
# Train Loss: 0.383
# Test Loss: 0.457
# Test Accuracy: 84.710
# Epoch 54
# Train Loss: 0.384
# Train Loss: 0.386
# Train Loss: 0.392
# Test Loss: 0.461
# Test Accuracy: 84.310
# Epoch 55
# Train Loss: 0.370
# Train Loss: 0.383
# Train Loss: 0.374
# Test Loss: 0.459
# Test Accuracy: 84.640
# Epoch 56
# Train Loss: 0.372
# Train Loss: 0.390
# Train Loss: 0.376
# Test Loss: 0.455
# Test Accuracy: 84.580
# Epoch 57
# Train Loss: 0.375
# Train Loss: 0.381
# Train Loss: 0.373
# Test Loss: 0.459
# Test Accuracy: 84.290
# Epoch 58
# Train Loss: 0.379
# Train Loss: 0.373
# Train Loss: 0.378
# Test Loss: 0.457
# Test Accuracy: 84.480
# Epoch 59
# Train Loss: 0.369
# Train Loss: 0.378
# Train Loss: 0.372
# Test Loss: 0.454
# Test Accuracy: 84.810
# Epoch 60
# Train Loss: 0.360
# Train Loss: 0.372
# Train Loss: 0.377
# Test Loss: 0.460
# Test Accuracy: 84.440
# Epoch 61
# Train Loss: 0.369
# Train Loss: 0.365
# Train Loss: 0.366
# Test Loss: 0.455
# Test Accuracy: 84.600
# Epoch 62
# Train Loss: 0.370
# Train Loss: 0.368
# Train Loss: 0.363
# Test Loss: 0.456
# Test Accuracy: 84.300
# Epoch 63
# Train Loss: 0.363
# Train Loss: 0.373
# Train Loss: 0.366
# Test Loss: 0.453
# Test Accuracy: 84.590
# Epoch 64
# Train Loss: 0.360
# Train Loss: 0.367
# Train Loss: 0.369
# Test Loss: 0.452
# Test Accuracy: 84.540
# Epoch 65
# Train Loss: 0.375
# Train Loss: 0.362
# Train Loss: 0.376
# Test Loss: 0.453
# Test Accuracy: 84.860
# Epoch 66
# Train Loss: 0.362
# Train Loss: 0.366
# Train Loss: 0.364
# Test Loss: 0.456
# Test Accuracy: 84.410
# Epoch 67
# Train Loss: 0.357
# Train Loss: 0.361
# Train Loss: 0.366
# Test Loss: 0.451
# Test Accuracy: 84.470
# Epoch 68
# Train Loss: 0.361
# Train Loss: 0.354
# Train Loss: 0.372
# Test Loss: 0.450
# Test Accuracy: 84.720
# Epoch 69
# Train Loss: 0.357
# Train Loss: 0.358
# Train Loss: 0.354
# Test Loss: 0.450
# Test Accuracy: 84.700
# Epoch 70
# Train Loss: 0.371
# Train Loss: 0.354
# Train Loss: 0.352
# Test Loss: 0.447
# Test Accuracy: 84.870
# Epoch 71
# Train Loss: 0.361
# Train Loss: 0.361
# Train Loss: 0.366
# Test Loss: 0.447
# Test Accuracy: 84.810
# Epoch 72
# Train Loss: 0.371
# Train Loss: 0.345
# Train Loss: 0.346
# Test Loss: 0.453
# Test Accuracy: 84.580
# Epoch 73
# Train Loss: 0.363
# Train Loss: 0.353
# Train Loss: 0.360
# Test Loss: 0.446
# Test Accuracy: 84.670
# Epoch 74
# Train Loss: 0.360
# Train Loss: 0.355
# Train Loss: 0.353
# Test Loss: 0.444
# Test Accuracy: 85.090
# Epoch 75
# Train Loss: 0.359
# Train Loss: 0.356
# Train Loss: 0.345
# Test Loss: 0.452
# Test Accuracy: 84.590
# Epoch 76
# Train Loss: 0.352
# Train Loss: 0.360
# Train Loss: 0.353
# Test Loss: 0.450
# Test Accuracy: 84.850
# Epoch 77
# Train Loss: 0.350
# Train Loss: 0.361
# Train Loss: 0.354
# Test Loss: 0.457
# Test Accuracy: 84.350
# Epoch 78
# Train Loss: 0.343
# Train Loss: 0.357
# Train Loss: 0.353
# Test Loss: 0.457
# Test Accuracy: 84.530
# Epoch 79
# Train Loss: 0.355
# Train Loss: 0.351
# Train Loss: 0.350
# Test Loss: 0.449
# Test Accuracy: 84.720
# Epoch 80
# Train Loss: 0.349
# Train Loss: 0.356
# Train Loss: 0.352
# Test Loss: 0.445
# Test Accuracy: 84.780
# Epoch 81
# Train Loss: 0.354
# Train Loss: 0.356
# Train Loss: 0.351
# Test Loss: 0.446
# Test Accuracy: 85.240
# Epoch 82
# Train Loss: 0.347
# Train Loss: 0.359
# Train Loss: 0.356
# Test Loss: 0.452
# Test Accuracy: 84.620
# Epoch 83
# Train Loss: 0.344
# Train Loss: 0.347
# Train Loss: 0.358
# Test Loss: 0.446
# Test Accuracy: 84.890
# Epoch 84
# Train Loss: 0.354
# Train Loss: 0.347
# Train Loss: 0.356
# Test Loss: 0.447
# Test Accuracy: 84.930
# Epoch 85
# Train Loss: 0.353
# Train Loss: 0.345
# Train Loss: 0.350
# Test Loss: 0.450
# Test Accuracy: 84.730
# Epoch 86
# Train Loss: 0.349
# Train Loss: 0.351
# Train Loss: 0.352
# Test Loss: 0.447
# Test Accuracy: 84.920
# Epoch 87
# Train Loss: 0.350
# Train Loss: 0.348
# Train Loss: 0.346
# Test Loss: 0.453
# Test Accuracy: 84.600
# Epoch 88
# Train Loss: 0.345
# Train Loss: 0.344
# Train Loss: 0.341
# Test Loss: 0.450
# Test Accuracy: 84.590
# Epoch 89
# Train Loss: 0.353
# Train Loss: 0.338
# Train Loss: 0.349
# Test Loss: 0.448
# Test Accuracy: 84.740
# Epoch 90
# Train Loss: 0.356
# Train Loss: 0.341
# Train Loss: 0.352
# Test Loss: 0.452
# Test Accuracy: 84.870
# Epoch 91
# Train Loss: 0.337
# Train Loss: 0.342
# Train Loss: 0.338
# Test Loss: 0.449
# Test Accuracy: 84.840
# Epoch 92
# Train Loss: 0.348
# Train Loss: 0.343
# Train Loss: 0.347
# Test Loss: 0.454
# Test Accuracy: 84.670
# Epoch 93
# Train Loss: 0.342
# Train Loss: 0.351
# Train Loss: 0.339
# Test Loss: 0.446
# Test Accuracy: 85.070
# Epoch 94
# Train Loss: 0.337
# Train Loss: 0.345
# Train Loss: 0.338
# Test Loss: 0.447
# Test Accuracy: 85.000
# Epoch 95
# Train Loss: 0.343
# Train Loss: 0.345
# Train Loss: 0.352
# Test Loss: 0.447
# Test Accuracy: 84.680
# Epoch 96
# Train Loss: 0.348
# Train Loss: 0.350
# Train Loss: 0.334
# Test Loss: 0.444
# Test Accuracy: 85.200
# Epoch 97
# Train Loss: 0.336
# Train Loss: 0.337
# Train Loss: 0.337
# Test Loss: 0.438
# Test Accuracy: 85.180
# Epoch 98
# Train Loss: 0.338
# Train Loss: 0.332
# Train Loss: 0.338
# Test Loss: 0.443
# Test Accuracy: 85.110
# Epoch 99
# Train Loss: 0.330
# Train Loss: 0.336
# Train Loss: 0.348
# Test Loss: 0.448
# Test Accuracy: 84.890
# Epoch 100
# Train Loss: 0.335
# Train Loss: 0.336
# Train Loss: 0.327
# Test Loss: 0.445
# Test Accuracy: 84.790
# Epoch 101
# Train Loss: 0.340
# Train Loss: 0.330
# Train Loss: 0.330
# Test Loss: 0.442
# Test Accuracy: 85.140
# Epoch 102
# Train Loss: 0.335
# Train Loss: 0.334
# Train Loss: 0.331
# Test Loss: 0.436
# Test Accuracy: 85.180
# Epoch 103
# Train Loss: 0.328
# Train Loss: 0.326
# Train Loss: 0.341
# Test Loss: 0.442
# Test Accuracy: 84.860
# Epoch 104
# Train Loss: 0.342
# Train Loss: 0.324
# Train Loss: 0.333
# Test Loss: 0.445
# Test Accuracy: 85.000
# Epoch 105
# Train Loss: 0.326
# Train Loss: 0.332
# Train Loss: 0.327
# Test Loss: 0.440
# Test Accuracy: 85.130
# Epoch 106
# Train Loss: 0.338
# Train Loss: 0.332
# Train Loss: 0.328
# Test Loss: 0.440
# Test Accuracy: 85.190
# Epoch 107
# Train Loss: 0.334
# Train Loss: 0.322
# Train Loss: 0.332
# Test Loss: 0.440
# Test Accuracy: 85.330
# Epoch 108
# Train Loss: 0.327
# Train Loss: 0.330
# Train Loss: 0.337
# Test Loss: 0.440
# Test Accuracy: 85.140
# Epoch 109
# Train Loss: 0.330
# Train Loss: 0.330
# Train Loss: 0.336
# Test Loss: 0.442
# Test Accuracy: 85.270
# Epoch 110
# Train Loss: 0.324
# Train Loss: 0.321
# Train Loss: 0.338
# Test Loss: 0.438
# Test Accuracy: 84.970
# Epoch 111
# Train Loss: 0.324
# Train Loss: 0.336
# Train Loss: 0.340
# Test Loss: 0.443
# Test Accuracy: 84.810
# Epoch 112
# Train Loss: 0.327
# Train Loss: 0.333
# Train Loss: 0.329
# Test Loss: 0.446
# Test Accuracy: 84.920
# Epoch 113
# Train Loss: 0.325
# Train Loss: 0.322
# Train Loss: 0.321
# Test Loss: 0.442
# Test Accuracy: 84.980
# Epoch 114
# Train Loss: 0.340
# Train Loss: 0.315
# Train Loss: 0.336
# Test Loss: 0.442
# Test Accuracy: 84.860
# Epoch 115
# Train Loss: 0.336
# Train Loss: 0.336
# Train Loss: 0.326
# Test Loss: 0.446
# Test Accuracy: 84.840
# Epoch 116
# Train Loss: 0.335
# Train Loss: 0.332
# Train Loss: 0.329
# Test Loss: 0.437
# Test Accuracy: 85.100
# Epoch 117
# Train Loss: 0.326
# Train Loss: 0.331
# Train Loss: 0.328
# Test Loss: 0.443
# Test Accuracy: 84.910
# Epoch 118
# Train Loss: 0.332
# Train Loss: 0.329
# Train Loss: 0.334
# Test Loss: 0.442
# Test Accuracy: 85.030
# Epoch 119
# Train Loss: 0.336
# Train Loss: 0.331
# Train Loss: 0.326
# Test Loss: 0.438
# Test Accuracy: 84.950
# Epoch 120
# Train Loss: 0.330
# Train Loss: 0.326
# Train Loss: 0.334
# Test Loss: 0.443
# Test Accuracy: 84.970
# Epoch 121
# Train Loss: 0.331
# Train Loss: 0.335
# Train Loss: 0.321
# Test Loss: 0.438
# Test Accuracy: 84.970
# Epoch 122
# Train Loss: 0.332
# Train Loss: 0.327
# Train Loss: 0.332
# Test Loss: 0.445
# Test Accuracy: 84.820
# Epoch 123
# Train Loss: 0.329
# Train Loss: 0.335
# Train Loss: 0.332
# Test Loss: 0.440
# Test Accuracy: 85.180
# Epoch 124
# Train Loss: 0.334
# Train Loss: 0.325
# Train Loss: 0.328
# Test Loss: 0.446
# Test Accuracy: 84.700
# Epoch 125
# Train Loss: 0.329
# Train Loss: 0.328
# Train Loss: 0.336
# Test Loss: 0.443
# Test Accuracy: 85.080
# Epoch 126
# Train Loss: 0.329
# Train Loss: 0.331
# Train Loss: 0.329
# Test Loss: 0.438
# Test Accuracy: 85.210
# Epoch 127
# Train Loss: 0.324
# Train Loss: 0.332
# Train Loss: 0.333
# Test Loss: 0.440
# Test Accuracy: 85.170
# Epoch 128
# Train Loss: 0.324
# Train Loss: 0.329
# Train Loss: 0.332
# Test Loss: 0.443
# Test Accuracy: 85.100
# Epoch 129
# Train Loss: 0.333
# Train Loss: 0.332
# Train Loss: 0.324
# Test Loss: 0.443
# Test Accuracy: 84.760
# Epoch 130
# Train Loss: 0.329
# Train Loss: 0.320
# Train Loss: 0.335
# Test Loss: 0.442
# Test Accuracy: 85.060
# Epoch 131
# Train Loss: 0.327
# Train Loss: 0.343
# Train Loss: 0.323
# Test Loss: 0.444
# Test Accuracy: 84.950
# Epoch 132
# Train Loss: 0.331
# Train Loss: 0.337
# Train Loss: 0.328
# Test Loss: 0.441
# Test Accuracy: 85.250
# Epoch 133
# Train Loss: 0.330
# Train Loss: 0.323
# Train Loss: 0.332
# Test Loss: 0.441
# Test Accuracy: 85.310
# Epoch 134
# Train Loss: 0.327
# Train Loss: 0.324
# Train Loss: 0.323
# Test Loss: 0.439
# Test Accuracy: 85.140
# Epoch 135
# Train Loss: 0.324
# Train Loss: 0.327
# Train Loss: 0.319
# Test Loss: 0.441
# Test Accuracy: 85.190
# Epoch 136
# Train Loss: 0.334
# Train Loss: 0.325
# Train Loss: 0.321
# Test Loss: 0.443
# Test Accuracy: 84.950
# Epoch 137
# Train Loss: 0.328
# Train Loss: 0.326
# Train Loss: 0.333
# Test Loss: 0.440
# Test Accuracy: 84.890
# Epoch 138
# Train Loss: 0.321
# Train Loss: 0.330
# Train Loss: 0.329
# Test Loss: 0.441
# Test Accuracy: 85.120
# Epoch 139
# Train Loss: 0.327
# Train Loss: 0.322
# Train Loss: 0.331
# Test Loss: 0.437
# Test Accuracy: 85.320
# Epoch 140
# Train Loss: 0.325
# Train Loss: 0.335
# Train Loss: 0.333
# Test Loss: 0.438
# Test Accuracy: 85.130
# Epoch 141
# Train Loss: 0.326
# Train Loss: 0.333
# Train Loss: 0.325
# Test Loss: 0.442
# Test Accuracy: 85.130
# Epoch 142
# Train Loss: 0.321
# Train Loss: 0.322
# Train Loss: 0.325
# Test Loss: 0.441
# Test Accuracy: 85.050
# Epoch 143
# Train Loss: 0.321
# Train Loss: 0.332
# Train Loss: 0.328
# Test Loss: 0.438
# Test Accuracy: 85.300
# Epoch 144
# Train Loss: 0.332
# Train Loss: 0.319
# Train Loss: 0.326
# Test Loss: 0.442
# Test Accuracy: 85.100
# Epoch 145
# Train Loss: 0.332
# Train Loss: 0.326
# Train Loss: 0.327
# Test Loss: 0.443
# Test Accuracy: 84.930
# Epoch 146
# Train Loss: 0.336
# Train Loss: 0.324
# Train Loss: 0.331
# Test Loss: 0.439
# Test Accuracy: 84.820
# Epoch 147
# Train Loss: 0.334
# Train Loss: 0.332
# Train Loss: 0.323
# Test Loss: 0.441
# Test Accuracy: 85.180
# Epoch 148
# Train Loss: 0.323
# Train Loss: 0.328
# Train Loss: 0.326
# Test Loss: 0.437
# Test Accuracy: 85.150
# Epoch 149
# Train Loss: 0.320
# Train Loss: 0.323
# Train Loss: 0.327
# Test Loss: 0.439
# Test Accuracy: 85.260
# Epoch 150
# Train Loss: 0.327
# Train Loss: 0.327
# Train Loss: 0.324
# Test Loss: 0.440
# Test Accuracy: 85.040
# Epoch 151
# Train Loss: 0.316
# Train Loss: 0.335
# Train Loss: 0.316
# Test Loss: 0.438
# Test Accuracy: 85.550
# Epoch 152
# Train Loss: 0.326
# Train Loss: 0.330
# Train Loss: 0.324
# Test Loss: 0.435
# Test Accuracy: 85.230
# Epoch 153
# Train Loss: 0.336
# Train Loss: 0.325
# Train Loss: 0.331
# Test Loss: 0.438
# Test Accuracy: 85.370
# Epoch 154
# Train Loss: 0.332
# Train Loss: 0.328
# Train Loss: 0.326
# Test Loss: 0.438
# Test Accuracy: 85.090
# Epoch 155
# Train Loss: 0.321
# Train Loss: 0.327
# Train Loss: 0.328
# Test Loss: 0.445
# Test Accuracy: 84.940
# Epoch 156
# Train Loss: 0.331
# Train Loss: 0.324
# Train Loss: 0.330
# Test Loss: 0.438
# Test Accuracy: 85.490
# Epoch 157
# Train Loss: 0.327
# Train Loss: 0.331
# Train Loss: 0.337
# Test Loss: 0.442
# Test Accuracy: 84.970
# Epoch 158
# Train Loss: 0.326
# Train Loss: 0.339
# Train Loss: 0.328
# Test Loss: 0.441
# Test Accuracy: 84.820
# Epoch 159
# Train Loss: 0.325
# Train Loss: 0.328
# Train Loss: 0.327
# Test Loss: 0.440
# Test Accuracy: 85.100
# Epoch 160
# Train Loss: 0.324
# Train Loss: 0.330
# Train Loss: 0.332
# Test Loss: 0.442
# Test Accuracy: 85.060
# Epoch 161
# Train Loss: 0.326
# Train Loss: 0.322
# Train Loss: 0.326
# Test Loss: 0.438
# Test Accuracy: 85.190
# Epoch 162
# Train Loss: 0.326
# Train Loss: 0.328
# Train Loss: 0.332
# Test Loss: 0.445
# Test Accuracy: 84.820
# Epoch 163
# Train Loss: 0.329
# Train Loss: 0.342
# Train Loss: 0.325
# Test Loss: 0.442
# Test Accuracy: 85.280
# Epoch 164
# Train Loss: 0.327
# Train Loss: 0.320
# Train Loss: 0.323
# Test Loss: 0.445
# Test Accuracy: 84.970
# Epoch 165
# Train Loss: 0.337
# Train Loss: 0.316
# Train Loss: 0.325
# Test Loss: 0.444
# Test Accuracy: 84.960
# Epoch 166
# Train Loss: 0.324
# Train Loss: 0.327
# Train Loss: 0.332
# Test Loss: 0.442
# Test Accuracy: 85.290
# Epoch 167
# Train Loss: 0.320
# Train Loss: 0.329
# Train Loss: 0.327
# Test Loss: 0.439
# Test Accuracy: 85.190
# Epoch 168
# Train Loss: 0.334
# Train Loss: 0.324
# Train Loss: 0.324
# Test Loss: 0.442
# Test Accuracy: 84.940
# Epoch 169
# Train Loss: 0.328
# Train Loss: 0.326
# Train Loss: 0.327
# Test Loss: 0.440
# Test Accuracy: 85.110
# Epoch 170
# Train Loss: 0.330
# Train Loss: 0.324
# Train Loss: 0.324
# Test Loss: 0.437
# Test Accuracy: 85.210
# Epoch 171
# Train Loss: 0.322
# Train Loss: 0.328
# Train Loss: 0.333
# Test Loss: 0.441
# Test Accuracy: 84.700
# Epoch 172
# Train Loss: 0.325
# Train Loss: 0.322
# Train Loss: 0.320
# Test Loss: 0.443
# Test Accuracy: 85.170
# Epoch 173
# Train Loss: 0.326
# Train Loss: 0.318
# Train Loss: 0.327
# Test Loss: 0.443
# Test Accuracy: 84.990
# Epoch 174
# Train Loss: 0.328
# Train Loss: 0.328
# Train Loss: 0.329
# Test Loss: 0.446
# Test Accuracy: 84.950
# Epoch 175
# Train Loss: 0.329
# Train Loss: 0.328
# Train Loss: 0.327
# Test Loss: 0.438
# Test Accuracy: 85.340
# Epoch 176
# Train Loss: 0.335
# Train Loss: 0.328
# Train Loss: 0.319
# Test Loss: 0.442
# Test Accuracy: 85.050
# Epoch 177
# Train Loss: 0.326
# Train Loss: 0.329
# Train Loss: 0.327
# Test Loss: 0.440
# Test Accuracy: 84.940
# Epoch 178
# Train Loss: 0.326
# Train Loss: 0.316
# Train Loss: 0.334
# Test Loss: 0.445
# Test Accuracy: 84.830
# Epoch 179
# Train Loss: 0.319
# Train Loss: 0.335
# Train Loss: 0.322
# Test Loss: 0.440
# Test Accuracy: 84.940
# Epoch 180
# Train Loss: 0.327
# Train Loss: 0.329
# Train Loss: 0.330
# Test Loss: 0.437
# Test Accuracy: 85.210
# Epoch 181
# Train Loss: 0.328
# Train Loss: 0.329
# Train Loss: 0.326
# Test Loss: 0.438
# Test Accuracy: 85.050
# Epoch 182
# Train Loss: 0.328
# Train Loss: 0.324
# Train Loss: 0.328
# Test Loss: 0.440
# Test Accuracy: 85.190
# Epoch 183
# Train Loss: 0.330
# Train Loss: 0.321
# Train Loss: 0.318
# Test Loss: 0.440
# Test Accuracy: 84.830
# Epoch 184
# Train Loss: 0.322
# Train Loss: 0.321
# Train Loss: 0.325
# Test Loss: 0.439
# Test Accuracy: 85.170
# Epoch 185
# Train Loss: 0.326
# Train Loss: 0.323
# Train Loss: 0.328
# Test Loss: 0.446
# Test Accuracy: 84.830
# Epoch 186
# Train Loss: 0.325
# Train Loss: 0.319
# Train Loss: 0.323
# Test Loss: 0.443
# Test Accuracy: 84.950
# Epoch 187
# Train Loss: 0.328
# Train Loss: 0.327
# Train Loss: 0.333
# Test Loss: 0.441
# Test Accuracy: 84.960
# Epoch 188
# Train Loss: 0.323
# Train Loss: 0.324
# Train Loss: 0.330
# Test Loss: 0.442
# Test Accuracy: 85.100
# Epoch 189
# Train Loss: 0.334
# Train Loss: 0.330
# Train Loss: 0.320
# Test Loss: 0.440
# Test Accuracy: 85.270
# Epoch 190
# Train Loss: 0.331
# Train Loss: 0.327
# Train Loss: 0.332
# Test Loss: 0.440
# Test Accuracy: 85.040
# Epoch 191
# Train Loss: 0.331
# Train Loss: 0.321
# Train Loss: 0.333
# Test Loss: 0.442
# Test Accuracy: 85.030
# Epoch 192
# Train Loss: 0.333
# Train Loss: 0.322
# Train Loss: 0.322
# Test Loss: 0.439
# Test Accuracy: 84.830
# Epoch 193
# Train Loss: 0.322
# Train Loss: 0.323
# Train Loss: 0.313
# Test Loss: 0.440
# Test Accuracy: 85.010
# Epoch 194
# Train Loss: 0.323
# Train Loss: 0.327
# Train Loss: 0.321
# Test Loss: 0.440
# Test Accuracy: 85.210
# Epoch 195
# Train Loss: 0.325
# Train Loss: 0.342
# Train Loss: 0.325
# Test Loss: 0.443
# Test Accuracy: 85.170
# Epoch 196
# Train Loss: 0.322
# Train Loss: 0.332
# Train Loss: 0.327
# Test Loss: 0.440
# Test Accuracy: 84.910
# Epoch 197
# Train Loss: 0.329
# Train Loss: 0.327
# Train Loss: 0.326
# Test Loss: 0.439
# Test Accuracy: 85.200
# Epoch 198
# Train Loss: 0.326
# Train Loss: 0.319
# Train Loss: 0.325
# Test Loss: 0.449
# Test Accuracy: 84.960
# Epoch 199
# Train Loss: 0.327
# Train Loss: 0.322
# Train Loss: 0.337
# Test Loss: 0.436
# Test Accuracy: 85.320
# Finished Training

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()
images_cuda, labels_cuda = images.to(device), labels.to(device)

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))

outputs = net(images_cuda)

# %% [markdown]
# # Final Results
#
# ## CIFAR-10 on 3-Layer MLP
# 1. No data augmentation = 52.2%
# 2. With data augmentation and Cutout = 46.64%
#
# Cutout probably makes the dataset too hard for MLP. Increasing the capacity of MLP may be able to improve accuracy
#
# ## CIFAR-10 on 3-Layer CNN
# 1. No data augmentation = 73.57%
# 2. With Data Augmentation and Cutout = 84.42% (Epoch 151)
# 3. With Data Augmentation, No Cutout, More Epochs, More Filters = 85.55% (Epoch 151)
